# %%
import pynbody
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.sans-serif'] = ['Tahoma','Lucida Grande','Verdana', 'DejaVu Sans']

pynbody.config['halo-class-priority'] =  [pynbody.halo.ahf.AHFCatalogue,
                                          pynbody.halo.GrpCatalogue,
                                          pynbody.halo.AmigaGrpCatalogue,
                                          pynbody.halo.legacy.RockstarIntermediateCatalogue,
                                          pynbody.halo.rockstar.RockstarCatalogue,
                                          pynbody.halo.subfind.SubfindCatalogue,
                                          pynbody.halo.hop.HOPCatalogue]


s = pynbody.load('../Data3/h148.cosmo50PLK.3072g3HbwK1BH/h148.cosmo50PLK.3072g3HbwK1BH.004096/h148.cosmo50PLK.3072g3HbwK1BH.004096')
h = s.halos()

# %%
children = [2, 3, 5, 6, 9, 11, 12, 14, 26, 28, 31, 42, 64, 77, 125, 252, 264, 271, 304, 372, 682] ## output of code above, copied here bc it takes long time to run

# %%
sat_SM = []
sat_Z = []
host_SM = []
host_Z = []


for i in range(1,13000): 
    if not h[i].properties['n_star'] == 0:
        sm = h[i].star.properties['M_star']
        halo = h.load_copy(i)
        halo.physical_units()
        z = np.sum(halo.stars['metals']*halo.stars['mass'])/halo.stars['mass'].sum()
        print(str(i)+": stellar mass",sm,'metallicity',z)
        if h[i].properties['hostHalo'] == -1:
            host_SM.append(sm) # add back to magnitude list
            host_Z.append(z)
        else:
            sat_SM.append(sm)
            sat_Z.append(z)
    
sat_SM  = np.array(sat_SM,dtype='float32')
sat_Z   = np.array(sat_Z,dtype='float32')
host_SM = np.array(host_SM,dtype='float32')
host_Z  = np.array(host_Z,dtype='float32')
# Out:
# 1: stellar mass 131026000000.0 metallicity 0.031064076565982757
# 2: stellar mass 1537420000.0 metallicity 0.004471985894649972
# 3: stellar mass 1018930000.0 metallicity 0.00446005829177357
# 5: stellar mass 292588000.0 metallicity 0.00260866737742371
# 6: stellar mass 224699000.0 metallicity 0.002241363743679699
# 7: stellar mass 20962300.0 metallicity 0.0044847575556253615
# 9: stellar mass 159888000.0 metallicity 0.002337122299814008
# 10: stellar mass 16621500.0 metallicity 0.001045169016379225
# 11: stellar mass 91704700.0 metallicity 0.001557212441452194
# 12: stellar mass 70728400.0 metallicity 0.0014040333467877824
# 13: stellar mass 41925300.0 metallicity 0.003291188115996225
# 14: stellar mass 8412860.0 metallicity 0.0008585273065773675
# 17: stellar mass 21390.5 metallicity 4.88458070284078e-05
# 18: stellar mass 2780090.0 metallicity 0.0005459938941747727
# 20: stellar mass 6818410.0 metallicity 0.001153801772133597
# 21: stellar mass 27942400.0 metallicity 0.003109313874282957
# 22: stellar mass 2090460.0 metallicity 0.0012959403162305589
# 23: stellar mass 2647930.0 metallicity 0.0005103001421729527
# 26: stellar mass 68041200.0 metallicity 0.0014828295517290543
# 27: stellar mass 4564680.0 metallicity 0.0013957719150536577
# 28: stellar mass 57037100.0 metallicity 0.0014351366166260057
# 30: stellar mass 253526 metallicity 0.0003106293078601244
# 31: stellar mass 2148880.0 metallicity 0.0005170233523414954
# 32: stellar mass 911708 metallicity 0.0005031017389267764
# 34: stellar mass 2512000.0 metallicity 0.000495972711768298
# 36: stellar mass 3902910.0 metallicity 0.0005550439344312305
# 37: stellar mass 86368.9 metallicity 0.0001787786429382015
# 38: stellar mass 19979.8 metallicity 6.0496506896665895e-05
# 40: stellar mass 821044 metallicity 0.000543389826700341
# 41: stellar mass 354222 metallicity 0.00044496307368610153
# 42: stellar mass 9311210.0 metallicity 0.000696496139270525
# 45: stellar mass 86261.7 metallicity 0.00014972083606289185
# 46: stellar mass 6657.05 metallicity 2.734294798648471e-06
# 48: stellar mass 670315 metallicity 0.0005428709864487691
# 55: stellar mass 23304 metallicity 0.00012038888476086962
# 57: stellar mass 723393 metallicity 0.0003685658727573139
# 58: stellar mass 293215 metallicity 0.0003234554098186763
# 60: stellar mass 13320.4 metallicity 0.00012451126461959417
# 64: stellar mass 1912930.0 metallicity 0.00034310495435498095
# 71: stellar mass 2258370.0 metallicity 0.001164884989766693
# 73: stellar mass 59376.9 metallicity 0.0001992811606387488
# 77: stellar mass 20337500.0 metallicity 0.0007929531000046284
# 80: stellar mass 9985.57 metallicity 1.0439861428310299e-05
# 91: stellar mass 225778 metallicity 0.00012369422485388403
# 94: stellar mass 616665 metallicity 0.0003025106311658321
# 95: stellar mass 108099 metallicity 0.00024974780803895344
# 99: stellar mass 16648.4 metallicity 4.095369987712509e-05
# 106: stellar mass 2197810.0 metallicity 0.0010989862263670988
# 115: stellar mass 56637.7 metallicity 0.00012990731397801816
# 121: stellar mass 21390.5 metallicity 4.88458070284078e-05
# 125: stellar mass 886568 metallicity 0.0003017384155662485
# 126: stellar mass 244517 metallicity 0.00023507761277889833
# 131: stellar mass 119941 metallicity 0.00015690854813900197
# 140: stellar mass 90196 metallicity 0.0002500342526945301
# 143: stellar mass 117933 metallicity 0.0001776293973872418
# 160: stellar mass 2463270.0 metallicity 0.00042945281277731424
# 223: stellar mass 146587 metallicity 0.00011457861571017067
# 252: stellar mass 499933 metallicity 0.0002350670817023141
# 264: stellar mass 1459890.0 metallicity 0.0004045313273382694
# 271: stellar mass 1398480.0 metallicity 0.0004270590734539336
# 304: stellar mass 2699850.0 metallicity 0.0004390578295045891
# 353: stellar mass 9985.59 metallicity 1.4337941433235598e-05
# 372: stellar mass 736467 metallicity 0.0002672411257707105
# 373: stellar mass 33295.8 metallicity 6.751833978340841e-05
# 435: stellar mass 33313.6 metallicity 0.00029303082585518974
# 465: stellar mass 163285 metallicity 0.00026632756527561263
# 590: stellar mass 16650.2 metallicity 7.613490435263415e-05
# 647: stellar mass 81128.2 metallicity 7.419457862872601e-07
# 677: stellar mass 276577 metallicity 0.00017622701636083184
# 682: stellar mass 3501590.0 metallicity 0.0010140252283259172
# 738: stellar mass 76633.2 metallicity 0.0002451200073190411
# 869: stellar mass 3328.53 metallicity 0.0
# 961: stellar mass 19992.7 metallicity 0.00031418967923589895
# 980: stellar mass 313204 metallicity 0.0002424564654421404
# 1146: stellar mass 3328.52 metallicity 0.0
# 1155: stellar mass 66639.5 metallicity 0.00010358802616461809
# 1381: stellar mass 293257 metallicity 0.0001959535977375853
# 2792: stellar mass 176646 metallicity 0.0002599563288754993
# 4897: stellar mass 9987.17 metallicity 5.7204496891689114e-05
# 10814: stellar mass 266668 metallicity 0.00035944133786928984

# %%
import pandas as pd
name = "simple_metallicity_calculation"
df = pd.DataFrame({"sat_SM" : sat_SM, "sat_Z" : sat_Z})
df.to_csv(name+"_sat.csv", index=False)
df = pd.DataFrame({"host_SM": host_SM, "host_Z": host_Z})
df.to_csv(name+"_host.csv", index=False)

# %%
colnames = ['sat_SM', 'sat_Z']
data = pd.read_csv(name+"_sat.csv", names=colnames)
sat_SM  = np.array(data.sat_SM.tolist()[1:],  dtype='float32')
sat_Z   = np.array(data.sat_Z.tolist()[1:],   dtype='float32')
colnames = ['host_SM', 'host_Z']
data = pd.read_csv(name+"_host.csv", names=colnames)
host_SM = np.array(data.host_SM.tolist()[1:], dtype='float32')
host_Z  = np.array(data.host_Z.tolist()[1:],  dtype='float32')

# %%
mpl.rc('text', usetex=True)

plt.figure(figsize=(4,2.5),dpi=200)
plt.scatter(sat_SM,sat_Z,marker='D',linewidth=0.5,s=15,facecolors='none',edgecolors='k',label='sim - Sat')
plt.scatter(host_SM,host_Z,marker='D',linewidth=0.5,s=15,facecolors='none',edgecolors='r',label='sim - Host')
plt.loglog()
plt.ylim(5e-7,1e-2)
plt.xlabel(r'$M_* \ (M_{\odot})$')
plt.ylabel(r'$Z$')
plt.title('Stellar Mass — Metallicity Relation')
plt.legend(loc=4,prop={'size': 8})
plt.gcf().subplots_adjust(bottom=0.3)
plt.gcf().subplots_adjust(left=0.2)
plt.savefig('smz_simp.png',dpi=300)
plt.show()

# %%
sat_SM = []
sat_Z = []
host_SM = []
host_Z = []


for i in range(1,13000): 
    if not h[i].properties['n_star'] == 0:
        sm = h[i].star.properties['M_star']
        print(str(i)+": stellar mass: "+str(sm),end=" ")
        halo = h.load_copy(i)
        halo.physical_units()
        
        z = np.sum(halo.star['feh'] * halo.star['mass'])/sm
        
        print('metallicity: '+str(z))
        if h[i].properties['hostHalo'] == -1:
            host_SM.append(sm) # add back to magnitude list
            host_Z.append(z)
        else:
            sat_SM.append(sm)
            sat_Z.append(z)
    
sat_SM  = np.array(sat_SM,dtype='float32')
sat_Z   = np.array(sat_Z,dtype='float32')
host_SM = np.array(host_SM,dtype='float32')
host_Z  = np.array(host_Z,dtype='float32')
# Out:
# 1: stellar mass: 131026000000.0 metallicity: -0.07005480178561992
# 2: stellar mass: 1537420000.0 metallicity: -1.3005851425284372
# 3: stellar mass: 1018930000.0 metallicity: -1.6520845940691384
# 5: stellar mass: 292588000.0 metallicity: -1.6561042487510227
# 6: stellar mass: 224699000.0 metallicity: -1.8798109335823487
# 7: stellar mass: 20962300.0 metallicity: -1.5652625561168825
# 9: stellar mass: 159888000.0 metallicity: -1.8590431544006498
# 10: stellar mass: 16621500.0 metallicity: -2.348904734211095
# 11: stellar mass: 91704700.0 metallicity: -1.9332365744747353
# 12: stellar mass: 70728400.0 metallicity: -2.2475331584667906
# 13: stellar mass: 41925300.0 metallicity: -1.52458638246937
# 14: stellar mass: 8412860.0 metallicity: -2.61812346890801
# 17: stellar mass: 21390.5 metallicity: -5.549736408178193
# 18: stellar mass: 2780090.0 metallicity: -2.860249463029529
# 20: stellar mass: 6818410.0 metallicity: -2.1666273774507716
# 21: stellar mass: 27942400.0 metallicity: -1.5544743663696754
# 22: stellar mass: 2090460.0 metallicity: -2.1582348504846602
# 23: stellar mass: 2647930.0 metallicity: -2.92017242210168
# 26: stellar mass: 68041200.0 metallicity: -1.9772185715029151
# 27: stellar mass: 4564680.0 metallicity: -2.1238078202993775
# 28: stellar mass: 57037100.0 metallicity: -2.0359876218797104
# 30: stellar mass: 253526 metallicity: -6.588417313788536
# 31: stellar mass: 2148880.0 metallicity: -3.1747689886542516
# 32: stellar mass: 911708 metallicity: -3.116916754316554
# 34: stellar mass: 2512000.0 metallicity: -3.2599732574276477
# 36: stellar mass: 3902910.0 metallicity: -2.7056672319922574
# 37: stellar mass: 86368.9 metallicity: -10.360371235971254
# 38: stellar mass: 19979.8 metallicity: -64.99868450483767
# 40: stellar mass: 821044 metallicity: -2.776988479476235
# 41: stellar mass: 354222 metallicity: -5.503775526045205
# 42: stellar mass: 9311210.0 metallicity: -2.663552271064701
# 45: stellar mass: 86261.7 metallicity: -4.51938819280663
# 46: stellar mass: 6657.05 metallicity: -76.29322210985302
# 48: stellar mass: 670315 metallicity: -3.085024813117667
# 55: stellar mass: 23304 metallicity: -42.146543643575434
# 57: stellar mass: 723393 metallicity: -3.025281347549397
# 58: stellar mass: 293215 metallicity: -3.2748516669262764
# 60: stellar mass: 13320.4 metallicity: -56.27855220042438
# 64: stellar mass: 1912930.0 metallicity: -3.0509764760856664
# 71: stellar mass: 2258370.0 metallicity: -2.3428112020486966
# 73: stellar mass: 59376.9 metallicity: -4.464845198526169
# 77: stellar mass: 20337500.0 metallicity: -2.544233478639069
# 80: stellar mass: 9985.57 metallicity: -119.89856191451295
# 91: stellar mass: 225778 metallicity: -3.956325439375492
# 94: stellar mass: 616665 metallicity: -5.340226388497287
# 95: stellar mass: 108099 metallicity: -5.092367794146022
# 99: stellar mass: 16648.4 metallicity: -4.6043041938475735
# 106: stellar mass: 2197810.0 metallicity: -2.6873363480717005
# 115: stellar mass: 56637.7 metallicity: -7.869402191685982
# 121: stellar mass: 21390.5 metallicity: -5.549736408178193
# 125: stellar mass: 886568 metallicity: -3.47357332804867
# 126: stellar mass: 244517 metallicity: -5.914990056600305
# 131: stellar mass: 119941 metallicity: -9.076432785046684
# 140: stellar mass: 90196 metallicity: -4.985972182469979
# 143: stellar mass: 117933 metallicity: -5.036681850351353
# 160: stellar mass: 2463270.0 metallicity: -3.0583018785884253
# 223: stellar mass: 146587 metallicity: -8.423588266550297
# 252: stellar mass: 499933 metallicity: -4.125295324577095
# 264: stellar mass: 1459890.0 metallicity: -3.1638804262655214
# 271: stellar mass: 1398480.0 metallicity: -2.8687530374107815
# 304: stellar mass: 2699850.0 metallicity: -3.358785531186995
# 353: stellar mass: 9985.59 metallicity: -39.325377503224196
# 372: stellar mass: 736467 metallicity: -6.238775580828254
# 373: stellar mass: 33295.8 metallicity: -15.92811306821267
# 435: stellar mass: 33313.6 metallicity: -19.856093617473157
# 465: stellar mass: 163285 metallicity: -6.648645873048426
# 590: stellar mass: 16650.2 metallicity: -33.5376705375824
# 647: stellar mass: 81128.2 metallicity: -269.87935330599566
# 677: stellar mass: 276577 metallicity: -4.3255315938502035
# 682: stellar mass: 3501590.0 metallicity: -2.3441120695674496
# 738: stellar mass: 76633.2 metallicity: -10.910787351448208
# 869: stellar mass: 3328.53 metallicity: -202.79383900867137
# 961: stellar mass: 19992.7 metallicity: -38.77923068637672
# 980: stellar mass: 313204 metallicity: -3.7213388904670137
# 1146: stellar mass: 3328.52 metallicity: -241.26319037084602
# 1155: stellar mass: 66639.5 metallicity: -10.648083626691893
# 1381: stellar mass: 293257 metallicity: -5.43271663139857
# 2792: stellar mass: 176646 metallicity: -7.079139137258807
# 4897: stellar mass: 9987.17 metallicity: -4.553056062564195
# 10814: stellar mass: 266668 metallicity: -2.8117678313303758

# %%
import pandas as pd
name = "iron_metallicity_calculation.csv"
df = pd.DataFrame({"sat_SM" : sat_SM, "sat_Z" : sat_Z})
df.to_csv(name+"_sat.csv", index=False)
df = pd.DataFrame({"host_SM": host_SM, "host_Z": host_Z})
df.to_csv(name+"_host.csv", index=False)

# %%
colnames = ['sat_SM', 'sat_Z']
data = pd.read_csv(name+"_sat.csv", names=colnames)
sat_SM  = np.array(data.sat_SM.tolist()[1:],  dtype='float32')
sat_Z   = np.array(data.sat_Z.tolist()[1:],   dtype='float32')
colnames = ['host_SM', 'host_Z']
data = pd.read_csv(name+"_host.csv", names=colnames)
host_SM = np.array(data.host_SM.tolist()[1:], dtype='float32')
host_Z  = np.array(data.host_Z.tolist()[1:],  dtype='float32')

# %%
## Milky Way Data from Kirby et. al. 2013
Kirby_logSM = np.array([7.39,6.69,6.59,6.07,5.84,5.73,5.51,5.48,4.57,4.28,3.93,3.90,3.73,3.68,3.14,
                        8.67,7.83,8.00,7.17,6.96,6.88,6.26,5.79,5.90,5.89,5.58,5.38,5.15])  # log_10(M*/Msol)
Kirby_logSMerr = np.array([0.14,0.13,0.21,0.13,0.20,0.20,0.10,0.09,0.14,0.13,0.13,0.20,0.23,0.22,0.13,
                        0.05,0.05,0.05,0.13,0.08,0.05,0.12,0.09,0.30,0.15,0.25,0.44,0.40])

Kirby_SM = np.power(10,Kirby_logSM)
Kirby_SMerr = 2.303 * Kirby_SM * Kirby_logSMerr ## error in SM is the error in 10^log(SM) = 2.303 * SM * logSM_err 
                                           ## (formula from https://terpconnect.umd.edu/~toh/models/ErrorPropagation.pdf)

Kirby_feh = np.array([-1.04,-1.45,-1.68,-1.63,-1.94,-2.13,-1.98,-1.91,-2.39,-2.10,-2.45,-2.12,-2.18,-2.25,-2.14,
                      -0.92,-1.12,-0.83,-1.62,-1.47,-1.33,-1.84,-1.94,-1.35,-1.70,-2.21,-1.93,-2.46])
Kirby_feherr = np.array([0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.01,0.04,0.03,0.07,0.05,0.05,0.04,0.05,
                      0.13,0.36,0.25,0.21,0.37,0.17,0.05,0.18,0.20,0.20,0.01,0.20,0.20])

# %%
mpl.rc('text', usetex=True)

plt.figure(figsize=(4,2.5),dpi=200)
plt.scatter(sat_SM,sat_Z,marker='D',linewidth=0.5,s=15,facecolors='none',edgecolors='k',label='sim - Sat',zorder=15)
plt.scatter(host_SM,host_Z,marker='D',linewidth=0.5,s=15,facecolors='none',edgecolors='r',label='sim - Host',zorder=10)
plt.errorbar(Kirby_SM,Kirby_feh,xerr=Kirby_SMerr,yerr=Kirby_feherr,
             fmt='o', marker='o', ms=5,lw=0.5,mew=0.3,mfc='none',mec='b',ecolor='b',label='Kirby et al. (2013)',zorder=5)
plt.semilogx()
plt.ylim(-10,0.5)
plt.xlabel(r'$M_* \ (M_{\odot})$')
plt.ylabel(r'[Fe/H]')
plt.title('Stellar Mass — Metallicity Relation')
plt.legend(loc=4,prop={'size': 7})
plt.gcf().subplots_adjust(bottom=0.3)
plt.gcf().subplots_adjust(left=0.2)
plt.savefig('smz_iron_zoomed.png',dpi=300)
plt.show()

plt.figure(figsize=(4,2.5),dpi=200)
plt.scatter(sat_SM,sat_Z,marker='D',linewidth=0.5,s=15,facecolors='none',edgecolors='k',label='sim - Sat',zorder=15)
plt.scatter(host_SM,host_Z,marker='D',linewidth=0.5,s=15,facecolors='none',edgecolors='r',label='sim - Host',zorder=10)
plt.semilogx()
plt.xlabel(r'$M_* \ (M_{\odot})$')
plt.ylabel(r'[Fe/H]')
plt.title('Stellar Mass — Metallicity Relation')
plt.legend(loc=4,prop={'size': 7})
plt.gcf().subplots_adjust(bottom=0.3)
plt.gcf().subplots_adjust(left=0.2)
plt.savefig('smz_iron.png',dpi=300)
plt.show()
